# %%
print("TEST...")
# Out:
# TEST...

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine


# Replace with your credentials
username = "postgres"
password = "ThePasswordis19!"
host = "localhost"
port = "5432"
database = "Vendor_Analysis"

# --- Create PostgreSQL connection engine ---
engine = create_engine(f'postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}')

# %%
# --- Load the aggregated table into a pandas DataFrame ---
df = pd.read_sql("SELECT * FROM vendor_sales_summary;", engine)

# %%
# Quick look at our dataframe
df.head()
# first 5 and last 5 look the same from our PostgreSQL table too 
df.tail()
# Out:
#        VendorNumber                   VendorName  Brand  \
# 10687         10754  PERFECTA WINES               25381
# 10688          9744  FREDERICK WILDMAN & SONS     25425
# 10689          9552  M S WALKER INC               25544
# 10690         10754  PERFECTA WINES               26442
# 10691          3252  E & J GALLO WINERY           17876
#
#                        Description  PurchasePrice  Actual_Price Volume  \
# 10687       Selbach-Oster Riesling          11.64         16.99    750
# 10688   La Scolca Black Label Gavi          24.82         35.99    750
# 10689        Tilia Bonarda Mendoza           7.94         11.99    750
# 10690  Fortant Heritage Lang Rouge          10.80         15.99    750
# 10691           Darkhorse Cab Svgn           5.33          7.99    750
#
#        Total_Purchase_Quantity  Total_Purchase_in_Dollars  \
# 10687                      6.0                      69.84
# 10688                     12.0                     297.84
# 10689                   1171.0                    9297.74
# 10690                   2477.0                   26751.60
# 10691                   9368.0                   49931.44
#
#        Total_Sales_Quantity  Total_Sales_in_Dollars  Total_Sales_Price  \
# 10687                  89.0                 1512.11            1121.34
# 10688                  12.0                  431.88              35.99
# 10689                 807.0                 8553.93            4977.35
# 10690                1462.0                23377.38           11688.69
# 10691                9179.0                73340.21           32511.31
#
#        Total_Excise_Tax  Freight_Cost
# 10687              9.83      28720.52
# 10688              1.35       3999.93
# 10689             89.61      55551.82
# 10690            162.81      28720.52
# 10691           1023.94      61966.91

# %%
# should tell us all about data types stored in each column 
df.dtypes
# Out:
# VendorNumber                   int64
# VendorName                    object
# Brand                          int64
# Description                   object
# PurchasePrice                float64
# Actual_Price                 float64
# Volume                        object
# Total_Purchase_Quantity      float64
# Total_Purchase_in_Dollars    float64
# Total_Sales_Quantity         float64
# Total_Sales_in_Dollars       float64
# Total_Sales_Price            float64
# Total_Excise_Tax             float64
# Freight_Cost                 float64
# dtype: object

# %%
# Lets check how many null values are present in our df


# AND Overall total amount of nulls within the whole df - so yea bunch of null values - present in our dataset
df.isnull().sum().sum()


# By columns - how many nulls
df.isnull().sum()

# NOTICE: 
# The columns that have a bunch of null values are these 4: 
# Total_Sales_Quantity, 
# Total_Sales_in_Dollars, 
# Total_Sales_Price,
# Total_Excise_Tax 


# WHAT MIGHT HAVE HAPPENED: 
# SO that means that the Vendor might've purchased them since Total_Purchase_Quantity - no nulls AND Total_Purchase_in_Dollars - no nulls either
# But most likely they were not sold
# Out:
# VendorNumber                   0
# VendorName                     0
# Brand                          0
# Description                    0
# PurchasePrice                  0
# Actual_Price                   0
# Volume                         0
# Total_Purchase_Quantity        0
# Total_Purchase_in_Dollars      0
# Total_Sales_Quantity         178
# Total_Sales_in_Dollars       178
# Total_Sales_Price            178
# Total_Excise_Tax             178
# Freight_Cost                   0
# dtype: int64

# %%
df["VendorName"].unique() # Uniques are returned in order of appearance 

# SO there's cleary a bunch of irrelevant blank spaces added to all of the VendorNames for some reason
# Out:
# array(['M S WALKER INC             ', 'PALM BAY INTERNATIONAL INC ',
#        'THE IMPORTED GRAPE LLC     ', 'SOUTHERN WINE & SPIRITS NE ',
#        'E & J GALLO WINERY         ', 'MARTIGNETTI COMPANIES',
#        'PSP WINES ', 'SAZERAC CO INC             ',
#        'CAMPARI AMERICA            ', 'PERFECTA WINES             ',
#        'DIAGEO NORTH AMERICA INC   ', 'MAJESTIC FINE WINES        ',
#        'JIM BEAM BRANDS COMPANY    ', 'STELLAR IMPORTING CO LLC   ',
#        'MHW LTD                    ', 'WINE GROUP INC             ',
#        'STATE WINE & SPIRITS   ', 'LATITUDE BEVERAGE COMPANY  ',
#        'Circa Wines                ', 'CONSTELLATION BRANDS INC   ',
#        'VINILANDIA USA             ', 'DELICATO VINEYARDS INC     ',
#        'STE MICHELLE WINE ESTATES  ', 'TREASURY WINE ESTATES      ',
#        'PROXIMO SPIRITS INC.       ', 'ULTRA BEVERAGE COMPANY LLP ',
#        'BROWN-FORMAN CORP          ', 'PREMIER DISTRIBUTORS       ',
#        'KOBRAND CORPORATION        ', 'PERNOD RICARD USA          ',
#        'DJINN SPIRITS LLC          ', 'MOET HENNESSY USA INC      ',
#        'LUXCO INC                  ', 'SAZERAC NORTH AMERICA INC. ',
#        'CANDIA VINEYARDS           ', 'WILLIAM GRANT & SONS INC   ',
#        'SURVILLE ENTERPRISES CORP  ', 'BACARDI USA INC            ',
#        'PINE STATE TRADING CO      ', 'MILTONS DISTRIBUTING CO    ',
#        'FREDERICK WILDMAN & SONS   ', 'Russian Standard Vodka     ',
#        'BANFI PRODUCTS CORP        ', 'TRINCHERO FAMILY ESTATES   ',
#        'STOLI GROUP,(USA) LLC      ', 'REMY COINTREAU USA INC     ',
#        'R.P.IMPORTS INC            ', 'SHAW ROSS INT L IMP LTD    ',
#        'PHILLIPS PRODUCTS CO.      ', 'VRANKEN AMERICA            ',
#        'CASTLE BRANDS CORP.        ', 'SEA HAGG DISTILLERY LLC    ',
#        'SIDNEY FRANK IMPORTING CO  ', 'FORTUNE WINE BROKERS LLC   ',
#        'VINEYARD BRANDS INC        ', 'SEA BREEZE CELLARS LLC     ',
#        'HEAVEN HILL DISTILLERIES   ', 'DIAGEO CHATEAU ESTATE WINES',
#        'JEWELL TOWNE VINEYARDS     ', 'MOONLIGHT MEADERY          ',
#        'PREMIUM PORT WINES, INC.   ', 'CRUSH WINES                ',
#        'TY KU LLC                  ', 'MCCORMICK DISTILLING CO    ',
#        'Dunn Wine Brokers          ', 'EDRINGTON AMERICAS         ',
#        'LAIRD & CO                 ', 'OLE SMOKY DISTILLERY LLC   ',
#        'CHARLES JACQUIN ET CIE INC ', 'BRONCO WINE COMPANY        ',
#        'VINEXTRA INC               ', 'BULLY BOY DISTILLERS       ',
#        'NICHE W & S                ', 'GILMANTON WINERY & VINEYARD',
#        'WESTERN SPIRITS BEVERAGE CO', 'TAMWORTH DISTILLING        ',
#        'LABELLE VYDS AND WINERY    ', 'UNCORKED       ',
#        'SOUTHERN GLAZERS W&S OF NE ', 'TRUETT HURST               ',
#        'KLIN SPIRITS LLC           ', 'FLAG HILL WINERY & VINEYARD',
#        'POVERTY LANE ORCHARDS      ', 'FULCHINO VINEYARD INC      ',
#        'HOOD RIVER DISTILLERS, Inc.', 'Serralles Usa LLC          ',
#        'INCREDIBREW INC            ', 'ZORVINO VINEYARDS          ',
#        'CALEDONIA SPIRITS INC      ', 'THE PIERPONT GROUP LLC     ',
#        'LOYAL DOG WINERY           ', 'DUGGANS DISTILLED PRODUCTS ',
#        'HIGHLAND WINE MERCHANTS LLC', 'APPOLO VINEYARDS LLC       ',
#        'DISARONNO INTERNATIONAL LLC', 'FABRIZIA SPIRITS LLC       ',
#        'BLACK PRINCE DISTILLERY INC', 'MARTIGNETTI COMPANIES ',
#        'STARK BREWING COMPANY      ', 'MARSALLE COMPANY           ',
#        'TAKARA SAKE USA INC        ', 'FANTASY FINE WINES CORP    ',
#        'AMERICAN VINTAGE BEVERAGE  ', 'PARK STREET IMPORTS LLC    ',
#        'WEIN BAUER INC             ', 'VINEYARD BRANDS LLC        ',
#        'SMOKY QUARTZ DISTILLERY LLC', 'AMERICAN SPIRITS EXCHANGE  ',
#        'CENTEUR IMPORTS LLC        ', 'ALTAMAR BRANDS LLC         ',
#        'ALISA CARR BEVERAGES           ',
#        'IRA GOLDMAN AND WILLIAMS, LLP          ',
#        'SWEETWATER FARM         ', 'ATLANTIC IMPORTING COMPANY ',
#        'SWEET BABY VINEYARD        ', 'VINEDREA WINES LLC         ',
#        'TALL SHIP DISTILLERY LLC   ', 'CAPSTONE INTERNATIONAL     ',
#        'FLAVOR ESSENCE INC         ', 'LAUREATE IMPORTS CO        ',
#        'BLACK ROCK SPIRITS LLC     ', 'HAUNTING WHISPER VYDS      ',
#        'ADAMBA IMPORTS INTL INC    ', 'MANGO BOTTLING INC         ',
#        'BLACK COVE BEVERAGES       ', 'WALPOLE MTN VIEW WINERY    ',
#        'STAR INDUSTRIES INC.       ', 'SILVER MOUNTAIN CIDERS     ',
#        'AAPER ALCOHOL & CHEMICAL CO'], dtype=object)

# %%
df["Description"].unique() # No blank spaces here
# Out:
# array(['Grahams 30-Yr Tawny Port', 'Bertani Amarone 04',
#        'Matanzas Creek Chard Sonoma', ..., 'Tilia Bonarda Mendoza',
#        'Fortant Heritage Lang Rouge', 'Darkhorse Cab Svgn'],
#       shape=(9651,), dtype=object)

# %%
df["Volume"].unique() # No blank spaces here: All unique values in Volume are numerical
# Volume is in an integer value - but for some reason the dtype is listed as an object - so we're gonna have to change it.
# Out:
# array(['750', '1500', '1000', '3000', '375', '1750', '50', '187', '4000',
#        '5000', '330', '300', '200', '180', '500', '100', '20000', '150',
#        '18000', '720', '400', '250', '162.5', '1100', '560', '6000',
#        '600', '19500', '650', '3750', '9000'], dtype=object)

# %%
df[df[['Total_Sales_Price', 'Total_Sales_Quantity', 'Total_Sales_in_Dollars', 'Total_Excise_Tax']].isnull().any(axis=1)]

# so looking at the null rows - we can clearly see  Clarifies it for eg;
# VendorNumber : 4692 & VendorName: KOBRAND CORPORATION purchased 6.0 of Brand: 27069 Description: Medici Ermete Concerto Lmbrs 
# Paying Total_Purchase_in_Dollars: 80.52 
# but Total_Sales_Quantity, Total_Sales_in_Dollars, Total_Sales_Price, Total_Excise_Tax	for this product do not exist (are NaN)
# Out:
# Empty DataFrame
# Columns: [VendorNumber, VendorName, Brand, Description, PurchasePrice, Actual_Price, Volume, Total_Purchase_Quantity, Total_Purchase_in_Dollars, Total_Sales_Quantity, Total_Sales_in_Dollars, Total_Sales_Price, Total_Excise_Tax, Freight_Cost]
# Index: []

# %%
# SO
# 1. lets change the Volume dtype to float, 

# 2. remove random blank spaces in VendorNames,

# 3. AND change the null values to 0 since there are values present for Total_Purchase_Quantity AND Total_Purchase_in_Dollars 
#       BUT 
#    the # Total_Sales_Quantity, Total_Sales_in_Dollars, Total_Sales_Price, Total_Excise_Tax for them are missing 
#    so --> purchases were made but none were sold - so these values must/should be 0.

# %%
df["Volume"] = df["Volume"].astype('float64')

# %%
df.dtypes # so we can see that it has been changed: Volume                       float64
# Out:
# VendorNumber                   int64
# VendorName                    object
# Brand                          int64
# Description                   object
# PurchasePrice                float64
# Actual_Price                 float64
# Volume                       float64
# Total_Purchase_Quantity      float64
# Total_Purchase_in_Dollars    float64
# Total_Sales_Quantity         float64
# Total_Sales_in_Dollars       float64
# Total_Sales_Price            float64
# Total_Excise_Tax             float64
# Freight_Cost                 float64
# dtype: object

# %%
df.fillna(0, inplace=True)

# %%
# lets check again 

df[df[["Total_Sales_Quantity", "Total_Sales_in_Dollars", "Total_Sales_Price", "Total_Excise_Tax"]].isnull().any(axis=1)]

# so we can see the output returns only column headers - no values - NONE at all are null anymore

# OR we can simply do this

df.isnull().sum().sum() # this has given us --> np.int64(0)

df.isnull().sum() # AND this gives us 0 in each column
# Out:
# VendorNumber                 0
# VendorName                   0
# Brand                        0
# Description                  0
# PurchasePrice                0
# Actual_Price                 0
# Volume                       0
# Total_Purchase_Quantity      0
# Total_Purchase_in_Dollars    0
# Total_Sales_Quantity         0
# Total_Sales_in_Dollars       0
# Total_Sales_Price            0
# Total_Excise_Tax             0
# Freight_Cost                 0
# dtype: int64

# %%
df["VendorName"] = df["VendorName"].str.strip()

# %%
df["VendorName"].unique() # so we can see blank spaces have been stripped away.
# Out:
# array(['M S WALKER INC', 'PALM BAY INTERNATIONAL INC',
#        'THE IMPORTED GRAPE LLC', 'SOUTHERN WINE & SPIRITS NE',
#        'E & J GALLO WINERY', 'MARTIGNETTI COMPANIES', 'PSP WINES',
#        'SAZERAC CO INC', 'CAMPARI AMERICA', 'PERFECTA WINES',
#        'DIAGEO NORTH AMERICA INC', 'MAJESTIC FINE WINES',
#        'JIM BEAM BRANDS COMPANY', 'STELLAR IMPORTING CO LLC', 'MHW LTD',
#        'WINE GROUP INC', 'STATE WINE & SPIRITS',
#        'LATITUDE BEVERAGE COMPANY', 'Circa Wines',
#        'CONSTELLATION BRANDS INC', 'VINILANDIA USA',
#        'DELICATO VINEYARDS INC', 'STE MICHELLE WINE ESTATES',
#        'TREASURY WINE ESTATES', 'PROXIMO SPIRITS INC.',
#        'ULTRA BEVERAGE COMPANY LLP', 'BROWN-FORMAN CORP',
#        'PREMIER DISTRIBUTORS', 'KOBRAND CORPORATION', 'PERNOD RICARD USA',
#        'DJINN SPIRITS LLC', 'MOET HENNESSY USA INC', 'LUXCO INC',
#        'SAZERAC NORTH AMERICA INC.', 'CANDIA VINEYARDS',
#        'WILLIAM GRANT & SONS INC', 'SURVILLE ENTERPRISES CORP',
#        'BACARDI USA INC', 'PINE STATE TRADING CO',
#        'MILTONS DISTRIBUTING CO', 'FREDERICK WILDMAN & SONS',
#        'Russian Standard Vodka', 'BANFI PRODUCTS CORP',
#        'TRINCHERO FAMILY ESTATES', 'STOLI GROUP,(USA) LLC',
#        'REMY COINTREAU USA INC', 'R.P.IMPORTS INC',
#        'SHAW ROSS INT L IMP LTD', 'PHILLIPS PRODUCTS CO.',
#        'VRANKEN AMERICA', 'CASTLE BRANDS CORP.',
#        'SEA HAGG DISTILLERY LLC', 'SIDNEY FRANK IMPORTING CO',
#        'FORTUNE WINE BROKERS LLC', 'VINEYARD BRANDS INC',
#        'SEA BREEZE CELLARS LLC', 'HEAVEN HILL DISTILLERIES',
#        'DIAGEO CHATEAU ESTATE WINES', 'JEWELL TOWNE VINEYARDS',
#        'MOONLIGHT MEADERY', 'PREMIUM PORT WINES, INC.', 'CRUSH WINES',
#        'TY KU LLC', 'MCCORMICK DISTILLING CO', 'Dunn Wine Brokers',
#        'EDRINGTON AMERICAS', 'LAIRD & CO', 'OLE SMOKY DISTILLERY LLC',
#        'CHARLES JACQUIN ET CIE INC', 'BRONCO WINE COMPANY',
#        'VINEXTRA INC', 'BULLY BOY DISTILLERS', 'NICHE W & S',
#        'GILMANTON WINERY & VINEYARD', 'WESTERN SPIRITS BEVERAGE CO',
#        'TAMWORTH DISTILLING', 'LABELLE VYDS AND WINERY', 'UNCORKED',
#        'SOUTHERN GLAZERS W&S OF NE', 'TRUETT HURST', 'KLIN SPIRITS LLC',
#        'FLAG HILL WINERY & VINEYARD', 'POVERTY LANE ORCHARDS',
#        'FULCHINO VINEYARD INC', 'HOOD RIVER DISTILLERS, Inc.',
#        'Serralles Usa LLC', 'INCREDIBREW INC', 'ZORVINO VINEYARDS',
#        'CALEDONIA SPIRITS INC', 'THE PIERPONT GROUP LLC',
#        'LOYAL DOG WINERY', 'DUGGANS DISTILLED PRODUCTS',
#        'HIGHLAND WINE MERCHANTS LLC', 'APPOLO VINEYARDS LLC',
#        'DISARONNO INTERNATIONAL LLC', 'FABRIZIA SPIRITS LLC',
#        'BLACK PRINCE DISTILLERY INC', 'STARK BREWING COMPANY',
#        'MARSALLE COMPANY', 'TAKARA SAKE USA INC',
#        'FANTASY FINE WINES CORP', 'AMERICAN VINTAGE BEVERAGE',
#        'PARK STREET IMPORTS LLC', 'WEIN BAUER INC', 'VINEYARD BRANDS LLC',
#        'SMOKY QUARTZ DISTILLERY LLC', 'AMERICAN SPIRITS EXCHANGE',
#        'CENTEUR IMPORTS LLC', 'ALTAMAR BRANDS LLC',
#        'ALISA CARR BEVERAGES', 'IRA GOLDMAN AND WILLIAMS, LLP',
#        'SWEETWATER FARM', 'ATLANTIC IMPORTING COMPANY',
#        'SWEET BABY VINEYARD', 'VINEDREA WINES LLC',
#        'TALL SHIP DISTILLERY LLC', 'CAPSTONE INTERNATIONAL',
#        'FLAVOR ESSENCE INC', 'LAUREATE IMPORTS CO',
#        'BLACK ROCK SPIRITS LLC', 'HAUNTING WHISPER VYDS',
#        'ADAMBA IMPORTS INTL INC', 'MANGO BOTTLING INC',
#        'BLACK COVE BEVERAGES', 'WALPOLE MTN VIEW WINERY',
#        'STAR INDUSTRIES INC.', 'SILVER MOUNTAIN CIDERS',
#        'AAPER ALCOHOL & CHEMICAL CO'], dtype=object)

# %%
# NOW we'll create some new columns in our df (or simply the vendor_performance_summary table)  
# which would be beneficial for our Analysis (EDA & Research questions + Testing) and even for our Power BI DashBoard later on

# %%
# We'll create these 4 new columns: Gross_Porfit, Profit_Margin, Stock_Turnover, Sales_to_Purchase_Ratio

df["Gross_Profit"] = df["Total_Sales_in_Dollars"] - df["Total_Purchase_in_Dollars"]

# %%
df["Profit_Margin"] = (df["Gross_Profit"]/df["Total_Sales_in_Dollars"].replace(0, np.nan))*100

# %%
df["Sales_to_Purchase_Ratio"] = (df["Total_Sales_in_Dollars"]/df["Total_Purchase_in_Dollars"].replace(0, np.nan))

# %%
# So we just added all of these: 
'''
df["Gross_Profit"] = df["Total_Sales_in_Dollars"] - df["Total_Purchase_in_Dollars"]
df["Profit_Margin"] = (df["Gross_Profit"]/df["Total_Sales_in_Dollars"].replace(0, np.nan))*100
df["Stock_Turnover"] = (df["Total_Sales_Quantity"]/df["Total_Purchase_Quantity"].replace(0, np.nan))
df["Sales_to_Purchase_Ratio"] = (df["Total_Sales_in_Dollars"]/df["Total_Purchase_in_Dollars"].replace(0, np.nan))  
'''

# %%
df # so yup created these new columns - DONE
# Out:
#        VendorNumber                  VendorName  Brand  \
# 0              9552              M S WALKER INC  10937
# 1              6785  PALM BAY INTERNATIONAL INC  18433
# 2              9552              M S WALKER INC  36571
# 3             90017      THE IMPORTED GRAPE LLC  45577
# 4              2000  SOUTHERN WINE & SPIRITS NE  32137
# ...             ...                         ...    ...
# 10687         10754              PERFECTA WINES  25381
# 10688          9744    FREDERICK WILDMAN & SONS  25425
# 10689          9552              M S WALKER INC  25544
# 10690         10754              PERFECTA WINES  26442
# 10691          3252          E & J GALLO WINERY  17876
#
#                        Description  PurchasePrice  Actual_Price  Volume  \
# 0         Grahams 30-Yr Tawny Port          61.64         89.99   750.0
# 1               Bertani Amarone 04          62.91         94.99   750.0
# 2      Matanzas Creek Chard Sonoma          16.33         25.99   750.0
# 3        Pacifico Sur Chard Curico           2.80          5.29   750.0
# 4           F Coppola Diamond Znfd           9.39         15.99   750.0
# ...                            ...            ...           ...     ...
# 10687       Selbach-Oster Riesling          11.64         16.99   750.0
# 10688   La Scolca Black Label Gavi          24.82         35.99   750.0
# 10689        Tilia Bonarda Mendoza           7.94         11.99   750.0
# 10690  Fortant Heritage Lang Rouge          10.80         15.99   750.0
# 10691           Darkhorse Cab Svgn           5.33          7.99   750.0
#
#        Total_Purchase_Quantity  Total_Purchase_in_Dollars  \
# 0                         15.0                     924.60
# 1                          7.0                     440.37
# 2                         12.0                     195.96
# 3                         72.0                     201.60
# 4                       1334.0                   12526.26
# ...                        ...                        ...
# 10687                      6.0                      69.84
# 10688                     12.0                     297.84
# 10689                   1171.0                    9297.74
# 10690                   2477.0                   26751.60
# 10691                   9368.0                   49931.44
#
#        Total_Sales_Quantity  Total_Sales_in_Dollars  Total_Sales_Price  \
# 0                      15.0                 1349.85             899.90
# 1                      63.0                 5984.37            4654.51
# 2                      21.0                  543.79             334.87
# 3                      69.0                  503.01              87.48
# 4                    1438.0                21723.62           15630.68
# ...                     ...                     ...                ...
# 10687                  89.0                 1512.11            1121.34
# 10688                  12.0                  431.88              35.99
# 10689                 807.0                 8553.93            4977.35
# 10690                1462.0                23377.38           11688.69
# 10691                9179.0                73340.21           32511.31
#
#        Total_Excise_Tax  Freight_Cost  Gross_Profit  Profit_Margin  \
# 0                  1.66      55551.82        425.25      31.503500
# 1                  6.93      13605.41       5544.00      92.641331
# 2                  2.34      55551.82        347.83      63.964030
# 3                  7.75         80.03        301.41      59.921274
# 4                158.93      19016.59       9197.36      42.338063
# ...                 ...           ...           ...            ...
# 10687              9.83      28720.52       1442.27      95.381288
# 10688              1.35       3999.93        134.04      31.036399
# 10689             89.61      55551.82       -743.81      -8.695535
# 10690            162.81      28720.52      -3374.22     -14.433696
# 10691           1023.94      61966.91      23408.77      31.918057
#
#        Stock_Turnover  Sales_to_Purchase_Ratio
# 0            1.000000                 1.459929
# 1            9.000000                13.589413
# 2            1.750000                 2.775005
# 3            0.958333                 2.495089
# 4            1.077961                 1.734246
# ...               ...                      ...
# 10687       14.833333                21.651060
# 10688        1.000000                 1.450040
# 10689        0.689155                 0.920001
# 10690        0.590230                 0.873868
# 10691        0.979825                 1.468818
#
# [10692 rows x 18 columns]

# %%
df.isnull().sum()
# Out:
# VendorNumber                   0
# VendorName                     0
# Brand                          0
# Description                    0
# PurchasePrice                  0
# Actual_Price                   0
# Volume                         0
# Total_Purchase_Quantity        0
# Total_Purchase_in_Dollars      0
# Total_Sales_Quantity           0
# Total_Sales_in_Dollars         0
# Total_Sales_Price              0
# Total_Excise_Tax               0
# Freight_Cost                   0
# Gross_Profit                   0
# Profit_Margin                178
# Stock_Turnover                 0
# Sales_to_Purchase_Ratio        0
# dtype: int64

# %%
df["Profit_Margin"].fillna(0, inplace=True)

# %%
df["Profit_Margin"].fillna(0, inplace=True)
# Out:
# C:\Users\shona\AppData\Local\Temp\ipykernel_1948\1511866893.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Profit_Margin"].fillna(0, inplace=True)

# %%
df.isnull().sum()
# Out:
# VendorNumber                 0
# VendorName                   0
# Brand                        0
# Description                  0
# PurchasePrice                0
# Actual_Price                 0
# Volume                       0
# Total_Purchase_Quantity      0
# Total_Purchase_in_Dollars    0
# Total_Sales_Quantity         0
# Total_Sales_in_Dollars       0
# Total_Sales_Price            0
# Total_Excise_Tax             0
# Freight_Cost                 0
# Gross_Profit                 0
# Profit_Margin                0
# Stock_Turnover               0
# Sales_to_Purchase_Ratio      0
# dtype: int64

# %%
df["Profit_Margin"] = df["Profit_Margin"].fillna(0)

# %%
df.isnull().sum()
# Out:
# VendorNumber                 0
# VendorName                   0
# Brand                        0
# Description                  0
# PurchasePrice                0
# Actual_Price                 0
# Volume                       0
# Total_Purchase_Quantity      0
# Total_Purchase_in_Dollars    0
# Total_Sales_Quantity         0
# Total_Sales_in_Dollars       0
# Total_Sales_Price            0
# Total_Excise_Tax             0
# Freight_Cost                 0
# Gross_Profit                 0
# Profit_Margin                0
# Stock_Turnover               0
# Sales_to_Purchase_Ratio      0
# dtype: int64

# %%
df.describe().T
# Out:
#                              count          mean            std           min  \
# VendorNumber               10692.0  10650.649458   18753.519148      2.000000
# Brand                      10692.0  18039.228769   12662.187074     58.000000
# PurchasePrice              10692.0     24.385303     109.269375      0.360000
# Actual_Price               10692.0     35.643671     148.246016      0.490000
# Volume                     10692.0    847.360550     664.309212     50.000000
# Total_Purchase_Quantity    10692.0   3140.886831   11095.086769      1.000000
# Total_Purchase_in_Dollars  10692.0  30106.693372  123067.799627      0.710000
# Total_Sales_Quantity       10692.0   3077.482136   10952.851391      0.000000
# Total_Sales_in_Dollars     10692.0  42239.074419  167655.265984      0.000000
# Total_Sales_Price          10692.0  18793.783627   44952.773386      0.000000
# Total_Excise_Tax           10692.0   1774.226259   10975.582240      0.000000
# Freight_Cost               10692.0  61433.763214   60938.458032      0.090000
# Gross_Profit               10692.0  12132.381048   46224.337964 -52002.780000
# Profit_Margin              10692.0    -15.620770     443.555329 -23730.638953
# Stock_Turnover             10692.0      1.706793       6.020460      0.000000
# Sales_to_Purchase_Ratio    10692.0      2.504390       8.459067      0.000000
#
#                                     25%           50%           75%  \
# VendorNumber                3951.000000   7153.000000   9552.000000
# Brand                       5793.500000  18761.500000  25514.250000
# PurchasePrice                  6.840000     10.455000     19.482500
# Actual_Price                  10.990000     15.990000     28.990000
# Volume                       750.000000    750.000000    750.000000
# Total_Purchase_Quantity       36.000000    262.000000   1975.750000
# Total_Purchase_in_Dollars    453.457500   3655.465000  20738.245000
# Total_Sales_Quantity          33.000000    261.000000   1929.250000
# Total_Sales_in_Dollars       729.220000   5298.045000  28396.915000
# Total_Sales_Price            289.710000   2857.800000  16059.562500
# Total_Excise_Tax               4.800000     46.570000    418.650000
# Freight_Cost               14069.870000  50293.620000  79528.990000
# Gross_Profit                  52.920000   1399.640000   8660.200000
# Profit_Margin                 13.324515     30.405457     39.956135
# Stock_Turnover                 0.807229      0.981529      1.039342
# Sales_to_Purchase_Ratio        1.153729      1.436894      1.665449
#
#                                     max
# VendorNumber               2.013590e+05
# Brand                      9.063100e+04
# PurchasePrice              5.681810e+03
# Actual_Price               7.499990e+03
# Volume                     2.000000e+04
# Total_Purchase_Quantity    3.376600e+05
# Total_Purchase_in_Dollars  3.811252e+06
# Total_Sales_Quantity       3.349390e+05
# Total_Sales_in_Dollars     5.101920e+06
# Total_Sales_Price          6.728193e+05
# Total_Excise_Tax           3.682428e+05
# Freight_Cost               2.570321e+05
# Gross_Profit               1.290668e+06
# Profit_Margin              9.971666e+01
# Stock_Turnover             2.745000e+02
# Sales_to_Purchase_Ratio    3.529286e+02

# %%
df[df["Total_Sales_Quantity"] < 0]
# Out:
# Empty DataFrame
# Columns: [VendorNumber, VendorName, Brand, Description, PurchasePrice, Actual_Price, Volume, Total_Purchase_Quantity, Total_Purchase_in_Dollars, Total_Sales_Quantity, Total_Sales_in_Dollars, Total_Sales_Price, Total_Excise_Tax, Freight_Cost, Gross_Profit, Profit_Margin, Stock_Turnover, Sales_to_Purchase_Ratio]
# Index: []

# %%
df[df["Total_Purchase_Quantity"] < 0]
# Out:
# Empty DataFrame
# Columns: [VendorNumber, VendorName, Brand, Description, PurchasePrice, Actual_Price, Volume, Total_Purchase_Quantity, Total_Purchase_in_Dollars, Total_Sales_Quantity, Total_Sales_in_Dollars, Total_Sales_Price, Total_Excise_Tax, Freight_Cost, Gross_Profit, Profit_Margin, Stock_Turnover, Sales_to_Purchase_Ratio]
# Index: []

# %%
df.duplicated().sum() # SO --> We have now confirmed that NO duplicate reocrds are present either 
# --> SO lets bring this cleaned table (With 4 new columns) back to our PostgreSQL Db
# Out:
# np.int64(0)

# %%
# So our engine has already been created variable engine - create engine - DONE -- now all we gotta do is push our df into the PostgreSQL Db

df.to_sql("vendor_sales_summary_clean_addedcols", engine, if_exists="replace", index=False)

print("Done, Added succesfully!")
# Out:
# Done, Added succesfully!
